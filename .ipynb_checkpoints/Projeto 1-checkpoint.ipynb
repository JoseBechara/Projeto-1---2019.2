# %% [markdown]
# # Projeto 1 - José Antônio Bechara

# %% [markdown]
# ### O ingresso na União Europeia contribuiu para a melhoria na qualidade de vida (IDH) e economia (PIB) dos países membros ?

# %% [markdown]
# ### Mecanismo:
# <br>
# https://europa.eu/european-union/about-eu/figures/economy_pt

# %% [markdown]
# #### De acordo com o próprio site da União Europeia, há uma enorme troca comercial entre seus países membros:
#
# ##### ("Mais de 64% das trocas comerciais dos países da UE realizam-se com outros países da UE. Embora a UE represente apenas 6,9% da população mundial, as suas trocas comerciais com o resto do mundo correspondem, aproximadamente, a 15,6% das exportações e importações mundiais.")
# #### Isso mostra que países membros podem ter sua economia fortificada por meio das trocas comerciais entre  eles mesmos e assim se tornarem uma economia fortificada e independente do resto dos países que não fazem parte da UE. <br> Com a economia mais consolidada é possível observar melhorias na qualidade de vida deste grupo.
#
# #### Vamos medir esses fatores por meio do PIB per capita, IDH e Importações (% do PIB), comparando os dados de antes com os dados após o ingresso na UE . Com a taxa de importações é possível ter um controle dos investimentos feitos aos países analisados e assim comparar com o PIB e o IDH para conseguir medir se houve ou não vantagem aos países se tornarem membros da União Europeia.

# %% [markdown]
# ### Países a serem analisados:
#
# #### Cyprus
# #### Czech Republic
# #### Estonia
# #### Hungary
# #### Latvia
# #### Lithuania
# #### Malta
# #### Poland
# #### Slovakia
# #### Slovenia
#
# ### Ano de ingresso: 2004

# %% [markdown]
# ### Links dos dados:
# https://data.worldbank.org/indicator/NE.IMP.GNFS.ZS
# <br>
# https://hdr.undp.org/en
# <br>
# http://gapm.io/dgdppc

# %% [markdown]
# ### Link para o GitHub:
# https://github.com/JoseBechara/Projeto-1---2019.2.git

# %% [markdown]
# #### De acordo com o próprio site da União Europeia, há uma enorme troca comercial entre seus países membros:
#
# ##### ("Mais de 64% das trocas comerciais dos países da UE realizam-se com outros países da UE. Embora a UE represente apenas 6,9% da população mundial, as suas trocas comerciais com o resto do mundo correspondem, aproximadamente, a 15,6% das exportações e importações mundiais.")
# #### Isso mostra que países membros podem ter sua economia fortificada por meio das trocas comerciais entre os eles mesmos e assim se tornarem uma economia fortificada e independente do resto dos países que não fazem parte da UE. <br> Com a economia mais consolidada é possível observar melhorias na qualidade de vida deste grupo.
#
# #### Vamos medir esses fatores por meio do PIB per capita, IDH e Importações (% do PIB). Com a taxa de importações é possível ter um controle dos investimentos feitos aos países analisados e assim comparar com o PIB e o IDH para conseguir medir se houve ou não vantagem aos países se tornarem membros da União Europeia.

# %% [markdown]
# ---

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import math as math
from scipy import stats
import matplotlib.pyplot as plt

# %%
#Leitura dos arquivos em Excel
IDH = pd.read_excel('Indicator_HDI.xlsx')
PIB = pd.read_excel('GDPpercapita.xlsx')
Exports = pd.read_excel('Exports(percent_of_GDP).xlsx')

# %% [markdown]
# ### Países membros da UE

# %%
UE = ["Austria", "Belgium", "Bulgaria", "Croatia", 
      "Cyprus", "Czech Republic", "Denmark", "Estonia", "Finland",
      "France", "Germany", "Greece", "Hungary", "Ireland",
      "Italy", "Latvia", "Lithuania", "Luxemburgo", "Malta",
      "Netherlands", "Poland", "Portugal", "Romania", "Slovak Republic",
      "Slovenia", "Spain", "Sweden", "United Kingdom"]

# %% [markdown]
# ## IDH

# %%
IDH.head()
# Out:
#                      HDI   1980   1990   2000   2005   2006   2007   2008  \
# 0               Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1            Afghanistan  0.198  0.246  0.230  0.340  0.354  0.363  0.370
# 2  Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                Albania    NaN  0.656  0.691  0.721  0.724  0.729  0.733
# 4                Algeria  0.454  0.551  0.624  0.667  0.673  0.680  0.686
#
#     2009   2011
# 0    NaN    NaN
# 1  0.387  0.398
# 2    NaN    NaN
# 3  0.734  0.739
# 4  0.691  0.698

# %% [markdown]
# ## PIB

# %%
PIB.head()
# Out:
#   Income per person (fixed 2000 US$)         1960         1961        1962  \
# 0                           Abkhazia          NaN          NaN         NaN
# 1                        Afghanistan          NaN          NaN         NaN
# 2              Akrotiri and Dhekelia          NaN          NaN         NaN
# 3                            Albania          NaN          NaN         NaN
# 4                            Algeria  1280.384828  1085.414612  855.947986
#
#          1963         1964         1965         1966         1967  \
# 0         NaN          NaN          NaN          NaN          NaN
# 1         NaN          NaN          NaN          NaN          NaN
# 2         NaN          NaN          NaN          NaN          NaN
# 3         NaN          NaN          NaN          NaN          NaN
# 4  1128.41578  1170.323896  1215.015783  1127.614288  1200.558225
#
#           1968     ...              2002         2003         2004  \
# 0          NaN     ...               NaN          NaN          NaN
# 1          NaN     ...               NaN          NaN          NaN
# 2          NaN     ...               NaN          NaN          NaN
# 3          NaN     ...       1313.722725  1381.040832  1454.022854
# 4  1291.863983     ...       1871.921986  1971.512803  2043.135713
#
#           2005         2006         2007         2008         2009  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3  1525.723589  1594.495067  1681.613910  1804.419415  1857.352947
# 4  2115.186028  2124.957754  2155.485231  2173.787903  2192.703976
#
#           2010         2011
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3  1915.424459  1965.707230
# 4  2231.980246  2255.225482
#
# [5 rows x 53 columns]

# %% [markdown]
# ## Exportações (% do PIB)

# %%
Exports.head()
# Out:
#   Exports of goods and services (% of GDP)       1961       1962       1963  \
# 0                                 Abkhazia        NaN        NaN        NaN
# 1                              Afghanistan   4.453443   4.878051   9.171601
# 2                    Akrotiri and Dhekelia        NaN        NaN        NaN
# 3                                  Albania        NaN        NaN        NaN
# 4                                  Algeria  46.244557  19.793872  24.684682
#
#         1964       1965       1966       1967       1968       1969  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1   8.888893  11.258279   8.571429   6.772908   8.899677  10.094637
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4  25.084059  22.603944  25.986197  23.434417  23.135635  23.788777
#
#      ...           2002       2003       2004       2005       2006  \
# 0    ...            NaN        NaN        NaN        NaN        NaN
# 1    ...      32.438501  42.295500  32.931170  30.550988  27.640178
# 2    ...            NaN        NaN        NaN        NaN        NaN
# 3    ...      20.419307  20.619399  21.542118  22.273069  25.090526
# 4    ...      35.076150  38.266470  40.071885  47.646353  48.607848
#
#         2007       2008       2009       2010       2011
# 0        NaN        NaN        NaN        NaN        NaN
# 1  22.926131  26.676120  22.860093  20.124519  18.106142
# 2        NaN        NaN        NaN        NaN        NaN
# 3  28.777169  29.511318  28.411549  32.427471  33.800932
# 4  46.609494  46.273658  29.289305  30.830405        NaN
#
# [5 rows x 52 columns]

# %% [markdown]
# ### Escolhendo o ano:

# %%
IDH_ano = IDH.loc[:, ["HDI", 1980, 1990, 2000, 2005, 2006, 2007, 2008, 2009, 2011]]
PIB_ano = PIB.loc[:,["Income per person (fixed 2000 US$)", 1980, 1990, 2000, 2005, 2006, 2007, 2008, 2009, 2011]]
Exports_ano = Exports.loc[:, ["Exports of goods and services (% of GDP)", 1980, 1990, 2000, 2005, 2006, 2007, 2008, 2009, 2011]]

# %%
IDH_ano.head()
# Out:
#                      HDI   1980   1990   2000   2005   2006   2007   2008  \
# 0               Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1            Afghanistan  0.198  0.246  0.230  0.340  0.354  0.363  0.370
# 2  Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                Albania    NaN  0.656  0.691  0.721  0.724  0.729  0.733
# 4                Algeria  0.454  0.551  0.624  0.667  0.673  0.680  0.686
#
#     2009   2011
# 0    NaN    NaN
# 1  0.387  0.398
# 2    NaN    NaN
# 3  0.734  0.739
# 4  0.691  0.698

# %%
PIB_ano.head()
# Out:
#   Income per person (fixed 2000 US$)         1980         1990         2000  \
# 0                           Abkhazia          NaN          NaN          NaN
# 1                        Afghanistan          NaN          NaN          NaN
# 2              Akrotiri and Dhekelia          NaN          NaN          NaN
# 3                            Albania  1060.684602   977.765530  1200.137437
# 4                            Algeria  1876.075639  1832.743369  1794.405233
#
#           2005         2006         2007         2008         2009  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3  1525.723589  1594.495067  1681.613910  1804.419415  1857.352947
# 4  2115.186028  2124.957754  2155.485231  2173.787903  2192.703976
#
#           2011
# 0          NaN
# 1          NaN
# 2          NaN
# 3  1965.707230
# 4  2255.225482

# %%
Exports_ano.head()
# Out:
#   Exports of goods and services (% of GDP)       1980       1990       2000  \
# 0                                 Abkhazia        NaN        NaN        NaN
# 1                              Afghanistan        NaN        NaN        NaN
# 2                    Akrotiri and Dhekelia        NaN        NaN        NaN
# 3                                  Albania  23.115588  14.869447  19.135535
# 4                                  Algeria  34.338461  23.443685  41.175353
#
#         2005       2006       2007       2008       2009       2011
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1  30.550988  27.640178  22.926131  26.676120  22.860093  18.106142
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3  22.273069  25.090526  28.777169  29.511318  28.411549  33.800932
# 4  47.646353  48.607848  46.609494  46.273658  29.289305        NaN

# %% [markdown]
# ### Mudando o índice:

# %%
IDH_idx = IDH_ano.set_index('HDI')
IDH_idx.head()
# Out:
#                         1980   1990   2000   2005   2006   2007   2008   2009  \
# HDI
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            0.198  0.246  0.230  0.340  0.354  0.363  0.370  0.387
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                  NaN  0.656  0.691  0.721  0.724  0.729  0.733  0.734
# Algeria                0.454  0.551  0.624  0.667  0.673  0.680  0.686  0.691
#
#                         2011
# HDI
# Abkhazia                 NaN
# Afghanistan            0.398
# Akrotiri and Dhekelia    NaN
# Albania                0.739
# Algeria                0.698

# %%
PIB_idx = PIB_ano.set_index('Income per person (fixed 2000 US$)')
PIB_idx.head()
# Out:
#                                            1980         1990         2000  \
# Income per person (fixed 2000 US$)
# Abkhazia                                    NaN          NaN          NaN
# Afghanistan                                 NaN          NaN          NaN
# Akrotiri and Dhekelia                       NaN          NaN          NaN
# Albania                             1060.684602   977.765530  1200.137437
# Algeria                             1876.075639  1832.743369  1794.405233
#
#                                            2005         2006         2007  \
# Income per person (fixed 2000 US$)
# Abkhazia                                    NaN          NaN          NaN
# Afghanistan                                 NaN          NaN          NaN
# Akrotiri and Dhekelia                       NaN          NaN          NaN
# Albania                             1525.723589  1594.495067  1681.613910
# Algeria                             2115.186028  2124.957754  2155.485231
#
#                                            2008         2009         2011
# Income per person (fixed 2000 US$)
# Abkhazia                                    NaN          NaN          NaN
# Afghanistan                                 NaN          NaN          NaN
# Akrotiri and Dhekelia                       NaN          NaN          NaN
# Albania                             1804.419415  1857.352947  1965.707230
# Algeria                             2173.787903  2192.703976  2255.225482

# %%
Exports_idx = Exports_ano.set_index('Exports of goods and services (% of GDP)')
Exports_idx.head()
# Out:
#                                                1980       1990       2000  \
# Exports of goods and services (% of GDP)
# Abkhazia                                        NaN        NaN        NaN
# Afghanistan                                     NaN        NaN        NaN
# Akrotiri and Dhekelia                           NaN        NaN        NaN
# Albania                                   23.115588  14.869447  19.135535
# Algeria                                   34.338461  23.443685  41.175353
#
#                                                2005       2006       2007  \
# Exports of goods and services (% of GDP)
# Abkhazia                                        NaN        NaN        NaN
# Afghanistan                               30.550988  27.640178  22.926131
# Akrotiri and Dhekelia                           NaN        NaN        NaN
# Albania                                   22.273069  25.090526  28.777169
# Algeria                                   47.646353  48.607848  46.609494
#
#                                                2008       2009       2011
# Exports of goods and services (% of GDP)
# Abkhazia                                        NaN        NaN        NaN
# Afghanistan                               26.676120  22.860093  18.106142
# Akrotiri and Dhekelia                           NaN        NaN        NaN
# Albania                                   29.511318  28.411549  33.800932
# Algeria                                   46.273658  29.289305        NaN

# %% [markdown]
# ### Adicionando coluna da UE

# %%
# i = 0
# for e in PIB_idx.index:
#     if e not in IDH_idx.index:
#         i+=1
#         print(e)
# print(i, "países diferentes!!")
        
# ### Os DataFrames possuem número diferente de países !!!

# %%
# i = 0
# for e in PIB_idx.index:
#     if e not in Exports_idx.index:
#         i+=1
#         print(e)
# print(i, "países diferentes!!")
        
# ### Os DataFrames possuem número diferente de países !!!

# %%
# Para o PIB:
Uniao_Europeia_PIB = []
for e in PIB_idx.index: 
    if e in UE: 
        Uniao_Europeia_PIB.append(True)
    else: 
        Uniao_Europeia_PIB.append(False)
        
# Para o IDH:
Uniao_Europeia_IDH = []
for e in IDH_idx.index: 
    if e in UE: 
        Uniao_Europeia_IDH.append(True)
    else: 
        Uniao_Europeia_IDH.append(False)
               
# Para o IDH:
Uniao_Europeia_Exports = []
for e in Exports_idx.index: 
    if e in UE: 
        Uniao_Europeia_Exports.append(True)
    else: 
        Uniao_Europeia_Exports.append(False)

# %%
PIB_idx["União Europeia"] = Uniao_Europeia_PIB
PIB_idx.head()
# Out:
#                                            1980         1990         2000  \
# Income per person (fixed 2000 US$)
# Abkhazia                                    NaN          NaN          NaN
# Afghanistan                                 NaN          NaN          NaN
# Akrotiri and Dhekelia                       NaN          NaN          NaN
# Albania                             1060.684602   977.765530  1200.137437
# Algeria                             1876.075639  1832.743369  1794.405233
#
#                                            2005         2006         2007  \
# Income per person (fixed 2000 US$)
# Abkhazia                                    NaN          NaN          NaN
# Afghanistan                                 NaN          NaN          NaN
# Akrotiri and Dhekelia                       NaN          NaN          NaN
# Albania                             1525.723589  1594.495067  1681.613910
# Algeria                             2115.186028  2124.957754  2155.485231
#
#                                            2008         2009         2011  \
# Income per person (fixed 2000 US$)
# Abkhazia                                    NaN          NaN          NaN
# Afghanistan                                 NaN          NaN          NaN
# Akrotiri and Dhekelia                       NaN          NaN          NaN
# Albania                             1804.419415  1857.352947  1965.707230
# Algeria                             2173.787903  2192.703976  2255.225482
#
#                                     União Europeia
# Income per person (fixed 2000 US$)
# Abkhazia                                     False
# Afghanistan                                  False
# Akrotiri and Dhekelia                        False
# Albania                                      False
# Algeria                                      False

# %%
IDH_idx["União Europeia"] = Uniao_Europeia_IDH
IDH_idx.head()
# Out:
#                         1980   1990   2000   2005   2006   2007   2008   2009  \
# HDI
# Abkhazia                 NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            0.198  0.246  0.230  0.340  0.354  0.363  0.370  0.387
# Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Albania                  NaN  0.656  0.691  0.721  0.724  0.729  0.733  0.734
# Algeria                0.454  0.551  0.624  0.667  0.673  0.680  0.686  0.691
#
#                         2011  União Europeia
# HDI
# Abkhazia                 NaN           False
# Afghanistan            0.398           False
# Akrotiri and Dhekelia    NaN           False
# Albania                0.739           False
# Algeria                0.698           False

# %%
Exports_idx["União Europeia"] = Uniao_Europeia_Exports
Exports_idx.head()
# Out:
#                                                1980       1990       2000  \
# Exports of goods and services (% of GDP)
# Abkhazia                                        NaN        NaN        NaN
# Afghanistan                                     NaN        NaN        NaN
# Akrotiri and Dhekelia                           NaN        NaN        NaN
# Albania                                   23.115588  14.869447  19.135535
# Algeria                                   34.338461  23.443685  41.175353
#
#                                                2005       2006       2007  \
# Exports of goods and services (% of GDP)
# Abkhazia                                        NaN        NaN        NaN
# Afghanistan                               30.550988  27.640178  22.926131
# Akrotiri and Dhekelia                           NaN        NaN        NaN
# Albania                                   22.273069  25.090526  28.777169
# Algeria                                   47.646353  48.607848  46.609494
#
#                                                2008       2009       2011  \
# Exports of goods and services (% of GDP)
# Abkhazia                                        NaN        NaN        NaN
# Afghanistan                               26.676120  22.860093  18.106142
# Akrotiri and Dhekelia                           NaN        NaN        NaN
# Albania                                   29.511318  28.411549  33.800932
# Algeria                                   46.273658  29.289305        NaN
#
#                                           União Europeia
# Exports of goods and services (% of GDP)
# Abkhazia                                           False
# Afghanistan                                        False
# Akrotiri and Dhekelia                              False
# Albania                                            False
# Algeria                                            False

# %% [markdown]
# ### Filtrando os países:

# %%
IDH_country = IDH_idx.loc[["Cyprus","Czech Republic","Estonia","Hungary","Latvia","Lithuania","Malta","Poland","Slovak Republic",
                           "Slovenia"],:]
IDH_country
# Out:
#                   1980   1990   2000   2005   2006   2007   2008   2009  \
# HDI
# Cyprus             NaN  0.747  0.800  0.809  0.814  0.819  0.827  0.837
# Czech Republic     NaN    NaN  0.816  0.854  0.858  0.861  0.864  0.863
# Estonia            NaN  0.717  0.776  0.821  0.829  0.834  0.832  0.828
# Hungary          0.700  0.706  0.775  0.803  0.808  0.809  0.811  0.811
# Latvia             NaN  0.693  0.732  0.784  0.793  0.800  0.803  0.798
# Lithuania          NaN    NaN  0.749  0.793  0.798  0.803  0.806  0.802
# Malta            0.703  0.753  0.799  0.825  0.825  0.826  0.829  0.827
# Poland             NaN    NaN  0.770  0.791  0.795  0.800  0.804  0.807
# Slovak Republic    NaN  0.747  0.779  0.810  0.817  0.825  0.831  0.829
# Slovenia           NaN    NaN  0.805  0.848  0.858  0.868  0.875  0.876
#
#                   2011  União Europeia
# HDI
# Cyprus           0.840            True
# Czech Republic   0.865            True
# Estonia          0.835            True
# Hungary          0.816            True
# Latvia           0.805            True
# Lithuania        0.810            True
# Malta            0.832            True
# Poland           0.813            True
# Slovak Republic  0.834            True
# Slovenia         0.884            True

# %%
PIB_country = PIB_idx.loc[["Cyprus","Czech Republic","Estonia","Hungary","Latvia","Lithuania","Malta",
                           "Poland","Slovak Republic","Slovenia"],:]
PIB_country
# Out:
#                                            1980          1990          2000  \
# Income per person (fixed 2000 US$)
# Cyprus                              6646.537210  10681.764801  13421.655416
# Czech Republic                              NaN   5401.379315   5724.837473
# Estonia                                     NaN           NaN   4143.927189
# Hungary                             3769.618011   4358.704324   4542.720720
# Latvia                              3201.325059   3912.245399   3300.934656
# Lithuania                                   NaN   4290.780128   3267.347443
# Malta                               5083.817093   6664.644459  10377.037318
# Poland                                      NaN   3100.706850   4454.080220
# Slovak Republic                             NaN   5316.213896   5330.401622
# Slovenia                                    NaN   8362.388736  10045.360077
#
#                                             2005          2006          2007  \
# Income per person (fixed 2000 US$)
# Cyprus                              14411.324179  14719.257659  15248.865286
# Czech Republic                       7020.190408   7488.669018   7868.316268
# Estonia                              5956.419264   6570.330139   7072.435864
# Hungary                              5639.394595   5868.301700   5884.140962
# Latvia                               5046.862474   5695.361455   6296.227116
# Lithuania                            4873.504234   5287.136551   5839.145602
# Malta                               10244.271054  10405.845964  10781.049690
# Poland                               5223.679776   5552.501270   5932.474410
# Slovak Republic                      6774.732012   7334.109759   8094.874509
# Slovenia                            11930.458610  12588.108384  13377.915330
#
#                                             2008          2009          2011  \
# Income per person (fixed 2000 US$)
# Cyprus                              15620.666109  15227.170457  15378.167043
# Czech Republic                       8041.974534   7633.493478   7926.938194
# Estonia                              6783.903384   5831.010546   6525.541272
# Hungary                              5947.158309   5551.426337   5745.981529
# Latvia                               6055.664808   4993.181194   5330.567994
# Lithuania                            6041.409020   5179.581644   5793.289777
# Malta                               11172.281543  10822.308022  11213.537003
# Poland                               6235.755172   6332.960478   6854.462537
# Slovak Republic                      8545.630996   8106.258155   8693.835279
# Slovenia                            13836.189224  12613.677971  12688.651676
#
#                                     União Europeia
# Income per person (fixed 2000 US$)
# Cyprus                                        True
# Czech Republic                                True
# Estonia                                       True
# Hungary                                       True
# Latvia                                        True
# Lithuania                                     True
# Malta                                         True
# Poland                                        True
# Slovak Republic                               True
# Slovenia                                      True

# %%
Exports_country = Exports_idx.loc[["Cyprus","Czech Republic","Estonia","Hungary","Latvia","Lithuania","Malta",
                                   "Poland","Slovak Republic","Slovenia"],:]
Exports_country
# Out:
#                                                1980       1990       2000  \
# Exports of goods and services (% of GDP)
# Cyprus                                    45.258449  51.500565  55.357646
# Czech Republic                                  NaN  39.367248  60.934044
# Estonia                                         NaN        NaN  84.594380
# Hungary                                   39.092771  31.144400  74.604377
# Latvia                                          NaN  47.709801  41.641793
# Lithuania                                       NaN  52.089552  44.747118
# Malta                                     80.933569  75.833623  90.557069
# Poland                                          NaN  26.195593  27.124391
# Slovak Republic                                 NaN  26.546762  70.448511
# Slovenia                                        NaN  90.759392  53.698978
#
#                                                2005       2006       2007  \
# Exports of goods and services (% of GDP)
# Cyprus                                    48.319417  48.004924  47.943825
# Czech Republic                            64.434254  66.974587  68.215761
# Estonia                                   77.718236  72.700137  67.072199
# Hungary                                   65.947113  77.744174  81.304559
# Latvia                                    47.849124  44.884350  42.346004
# Lithuania                                 57.532154  59.083761  54.091707
# Malta                                     76.814332  86.486540  89.219263
# Poland                                    37.085046  40.355046  40.757281
# Slovak Republic                           76.251902  84.489692  86.856007
# Slovenia                                  62.177976  66.540494  69.557316
#
#                                                2008       2009       2011  \
# Exports of goods and services (% of GDP)
# Cyprus                                    45.438769  40.269090        NaN
# Czech Republic                            64.447915  58.952429  72.547294
# Estonia                                   71.047915  65.054245  91.509209
# Hungary                                   81.659842  77.590688  92.265835
# Latvia                                    42.815954  43.887457  59.315726
# Lithuania                                 59.877387  54.629577  77.778616
# Malta                                     87.778691  78.776392  97.983732
# Poland                                    39.899187  39.443953        NaN
# Slovak Republic                           83.470074  70.877278  89.055331
# Slovenia                                  67.142397  58.389482  72.296709
#
#                                           União Europeia
# Exports of goods and services (% of GDP)
# Cyprus                                              True
# Czech Republic                                      True
# Estonia                                             True
# Hungary                                             True
# Latvia                                              True
# Lithuania                                           True
# Malta                                               True
# Poland                                              True
# Slovak Republic                                     True
# Slovenia                                            True

# %% [markdown]
# ### Criando um grupo de controle:

# %%
IDH_controle = IDH_idx.loc[["France", "Germany", "United Kingdom", "Italy"],:]
IDH_controle
# Out:
#                  1980   1990   2000   2005   2006   2007   2008  2009   2011  \
# HDI
# France          0.722  0.777  0.846  0.869  0.873  0.877  0.879  0.88  0.884
# Germany         0.730  0.795  0.864  0.895  0.898  0.901  0.902  0.90  0.905
# United Kingdom  0.744  0.778  0.833  0.855  0.853  0.856  0.860  0.86  0.863
# Italy           0.717  0.764  0.825  0.861  0.866  0.869  0.871  0.87  0.874
#
#                 União Europeia
# HDI
# France                    True
# Germany                   True
# United Kingdom            True
# Italy                     True

# %%
PIB_controle = PIB_idx.loc[["France", "Germany", "United Kingdom", "Italy"],:]
PIB_controle
# Out:
#                                             1980          1990          2000  \
# Income per person (fixed 2000 US$)
# France                              15641.971055  18731.662022  21774.992990
# Germany                             15798.695358  19600.843192  22945.708850
# United Kingdom                      15618.147420  20087.049737  25057.613530
# Italy                               13160.828125  16599.920089  19388.278751
#
#                                             2005          2006          2007  \
# Income per person (fixed 2000 US$)
# France                              22734.233318  23133.351135  23516.223173
# Germany                             23564.385168  24463.846469  25297.385393
# United Kingdom                      28354.039583  28913.096292  29771.303348
# Italy                               19781.958527  20102.230231  20291.226640
#
#                                             2008          2009          2011  \
# Income per person (fixed 2000 US$)
# France                              23366.402616  22508.762612  23016.847783
# Germany                             25620.075392  24368.195607  26206.548266
# United Kingdom                      29287.760417  27933.777671  28272.406612
# Italy                               19903.456942  18697.219786  18937.249984
#
#                                     União Europeia
# Income per person (fixed 2000 US$)
# France                                        True
# Germany                                       True
# United Kingdom                                True
# Italy                                         True

# %%
Exports_controle = Exports_idx.loc[["France", "Germany", "United Kingdom", "Italy"],:]
Exports_controle
# Out:
#                                                1980       1990       2000  \
# Exports of goods and services (% of GDP)
# France                                    21.400000  21.481234  28.813829
# Germany                                   20.222984  24.800129  33.384615
# United Kingdom                            27.140799  23.950039  27.713079
# Italy                                     21.038451  19.030436  26.768795
#
#                                                2005       2006       2007  \
# Exports of goods and services (% of GDP)
# France                                    26.359640  27.023517  26.856377
# Germany                                   41.317659  45.513635  47.165328
# United Kingdom                            26.959793  29.119376  26.918128
# Italy                                     25.873281  27.620084  28.851410
#
#                                                2008       2009       2011  \
# Exports of goods and services (% of GDP)
# France                                    26.948859  23.368963  26.955602
# Germany                                   48.152235  42.389556  50.173957
# United Kingdom                            29.811976  28.830278  32.493159
# Italy                                     28.456251  23.746868  28.839316
#
#                                           União Europeia
# Exports of goods and services (% of GDP)
# France                                              True
# Germany                                             True
# United Kingdom                                      True
# Italy                                               True

# %%
def reta(dados_x, dados_y, c):    
    a = dados_y.cov(dados_x) / dados_x.var()
    b = dados_y.mean() - a*dados_x.mean()

    
    plt.scatter(dados_x, dados_y, c=c, alpha=0.8)
    plt.xlabel('eixo x')
    plt.ylabel('eixo y')
    plt.plot((dados_x.min(), dados_x.max()), (a*dados_x.min()+b, a*dados_x.max()+b), color=c)

    plt.tight_layout()

# %%
PIB_country.loc[:,[2000, 2005, 2011]].plot.bar(title = "Análise");
PIB_controle.loc[:,[2000, 2005, 2011]].plot.bar(title = "Controle");

# %%
IDH_country.loc[:,[2000, 2005, 2011]].plot.bar(title = "Análise");
IDH_controle.loc[:,[2000, 2005, 2011]].plot.bar(title = "Controle");

# %%
Exports_country.loc[:,[2000, 2005, 2011]].plot.bar(title = "Análise");
Exports_controle.loc[:,[2000, 2005, 2011]].plot.bar(title = "Controle");

# %%
fig = plt.figure(figsize=(23,5))


plt.subplot(1,3,1)
plt.scatter(Exports_country.loc[:,2000], IDH_country.loc[:,2000], label = ("Análise"), c = "r")
plt.scatter(Exports_controle.loc[:,2000], IDH_controle.loc[:,2000], label = ("Controle"), c = "b")
plt.legend()
reta(Exports_country.loc[:,2000], IDH_country.loc[:,2000], "r")
reta(Exports_controle.loc[:,2000], IDH_controle.loc[:,2000], "b")
plt.title("2000")
plt.xlabel("Exports (% do PIB)")
plt.ylabel("IDH")
plt.grid(True)

plt.subplot(1,3,2)
plt.scatter(Exports_country.loc[:,2005], IDH_country.loc[:,2005], label = ("Análise"), c = "r")
plt.scatter(Exports_controle.loc[:,2005], IDH_controle.loc[:,2005], label = ("Controle"), c = "b")
plt.legend()
reta(Exports_country.loc[:,2005], IDH_country.loc[:,2005], "r")
reta(Exports_controle.loc[:,2005], IDH_controle.loc[:,2005], "b")
plt.title("2005")
plt.xlabel("Exports (% do PIB)")
plt.ylabel("IDH")
plt.grid(True)

plt.subplot(1,3,3)
plt.scatter(Exports_country.loc[:,2011], IDH_country.loc[:,2011], label = ("Análise"), c = "r")
plt.scatter(Exports_controle.loc[:,2011], IDH_controle.loc[:,2011], label = ("Controle"), c = "b")
plt.legend()
reta(Exports_country.loc[:,2011], IDH_country.loc[:,2011], "r")
reta(Exports_controle.loc[:,2011], IDH_controle.loc[:,2011], "b")
plt.title("2011")
plt.xlabel("Exports (% do PIB)")
plt.ylabel("IDH")
plt.grid(True)

plt.show()
